# %%
import numpy as np
import pandas as pd
from pandas import ExcelFile
from pandas import ExcelWriter
import requests, zipfile, io
import pyodbc
import sqlalchemy
from sqlalchemy import create_engine, MetaData, Table, Column, delete, insert, select, func, sql
from sqlalchemy.types import SmallInteger, Integer, String, Float, NVARCHAR
from datetime import datetime
import pprint
import urllib
import urllib.request
import copy
import os
import urllib3
urllib3.disable_warnings()

# %% [markdown]
# # autobuildicdb NPD - Download and QC Core Photo data

# %%
# IC database folder
dbdir = 'C:\ICData\Test3'

# Output folder
outdir = '{}\core_photo_jpgs'.format(dbdir)

# Create outdir folder within IC database folder
if not os.path.exists(outdir):
    os.mkdir(outdir)

# %% [markdown]
# ## Download Core Photos to file

# %%
# Main script outputs three files:
    # wellbore_core_photo_ERRONEOUS_withURL.csv (erroneous 'Core photo title' columns)
    # wellbore_core_photo_withURL.csv (final data with URLs)
    # wellbore_core_photo.csv (final data for IC)

# %% [markdown]
# ### Core Photos (one folder per well)

# %%
# df_core_photo_withURL

df = pd.read_csv('{}\output_data\wellbore_core_photo_withURL.csv'.format(dbdir))
df.head()
# Out:
#     Well  Core sample number Core photo title  \
# 0  1/2-1                   1   10208,10228,ft
# 1  1/2-1                   2   19228,10262,ft
# 2  1/2-1                   3   10262,10277,ft
# 3  1/2-1                   4   10277,10292,ft
# 4  1/2-1                   5   10292,10307,ft
#
#                                       Core photo URL  NPDID wellbore  \
# 0  https://factpages.npd.no/pbl/core_photo_jpgs/1...            1382
# 1  https://factpages.npd.no/pbl/core_photo_jpgs/1...            1382
# 2  https://factpages.npd.no/pbl/core_photo_jpgs/1...            1382
# 3  https://factpages.npd.no/pbl/core_photo_jpgs/1...            1382
# 4  https://factpages.npd.no/pbl/core_photo_jpgs/1...            1382
#
#    Top depth  Base depth Unit Folder  \
# 0  3111.3984   3117.4944   ft  1_2-1
# 1  5860.6944   3127.8576   ft  1_2-1
# 2  3127.8576   3132.4296   ft  1_2-1
# 3  3132.4296   3137.0016   ft  1_2-1
# 4  3137.0016   3141.5736   ft  1_2-1
#
#                                               Legend
# 0  .\core_photo_jpgs\1_2-1\1382_01_10208-10228ft.jpg
# 1  .\core_photo_jpgs\1_2-1\1382_02_19228-10262ft.jpg
# 2  .\core_photo_jpgs\1_2-1\1382_03_10262-10277ft.jpg
# 3  .\core_photo_jpgs\1_2-1\1382_04_10277-10292ft.jpg
# 4  .\core_photo_jpgs\1_2-1\1382_05_10292-10307ft.jpg

# %%
# Create subset of wells for which to save Core Photos

filt = (df['Well'].str.startswith('1/3'))
df = df[filt]
df
# Out:
#         Well  Core sample number Core photo title  \
# 12     1/3-3                   1      4129,4135,m
# 13     1/3-3                   2      4135,4141,m
# 14     1/3-3                   3      4141,4148,m
# 15     1/3-3                   4      4147,4186,m
# 16     1/3-3                   5      4186,4192,m
# ..       ...                 ...              ...
# 124  1/3-9 S                  17      4353,4358,m
# 125  1/3-9 S                  18      4358,4363,m
# 126  1/3-9 S                  20      4368,4373,m
# 127  1/3-9 S                  21      4373,4378,m
# 128  1/3-9 S                  22      4378,4378,m
#
#                                         Core photo URL  NPDID wellbore  \
# 12   https://factpages.npd.no/pbl/core_photo_jpgs/8...              87
# 13   https://factpages.npd.no/pbl/core_photo_jpgs/8...              87
# 14   https://factpages.npd.no/pbl/core_photo_jpgs/8...              87
# 15   https://factpages.npd.no/pbl/core_photo_jpgs/8...              87
# 16   https://factpages.npd.no/pbl/core_photo_jpgs/8...              87
# ..                                                 ...             ...
# 124  https://factpages.npd.no/pbl/core_photo_jpgs/3...            3362
# 125  https://factpages.npd.no/pbl/core_photo_jpgs/3...            3362
# 126  https://factpages.npd.no/pbl/core_photo_jpgs/3...            3362
# 127  https://factpages.npd.no/pbl/core_photo_jpgs/3...            3362
# 128  https://factpages.npd.no/pbl/core_photo_jpgs/3...            3362
#
#      Top depth  Base depth Unit   Folder  \
# 12      4129.0      4135.0    m    1_3-3
# 13      4135.0      4141.0    m    1_3-3
# 14      4141.0      4148.0    m    1_3-3
# 15      4147.0      4186.0    m    1_3-3
# 16      4186.0      4192.0    m    1_3-3
# ..         ...         ...  ...      ...
# 124     4353.0      4358.0    m  1_3-9 S
# 125     4358.0      4363.0    m  1_3-9 S
# 126     4368.0      4373.0    m  1_3-9 S
# 127     4373.0      4378.0    m  1_3-9 S
# 128     4378.0      4378.0    m  1_3-9 S
#
#                                                Legend
# 12       .\core_photo_jpgs\1_3-3\87_01_4129-4135m.jpg
# 13       .\core_photo_jpgs\1_3-3\87_02_4135-4141m.jpg
# 14       .\core_photo_jpgs\1_3-3\87_03_4141-4148m.jpg
# 15       .\core_photo_jpgs\1_3-3\87_04_4147-4186m.jpg
# 16       .\core_photo_jpgs\1_3-3\87_05_4186-4192m.jpg
# ..                                                ...
# 124  .\core_photo_jpgs\1_3-9 S\3362_17_4353-4358m.jpg
# 125  .\core_photo_jpgs\1_3-9 S\3362_18_4358-4363m.jpg
# 126  .\core_photo_jpgs\1_3-9 S\3362_20_4368-4373m.jpg
# 127  .\core_photo_jpgs\1_3-9 S\3362_21_4373-4378m.jpg
# 128  .\core_photo_jpgs\1_3-9 S\3362_22_4378-4378m.jpg
#
# [117 rows x 10 columns]

# %%
# See https://stackabuse.com/download-files-with-python/
# Using the request Module

# Would also be useful to create folders for each wellbore

def save_core_photo():
    
    for index, row in df.iterrows(): 
        # Using filterered dataframe for speed
        
        url = row['Core photo URL']
        filename = url.split('/')[-1]

        print('Beginning file download with requests: ', url)
        r = requests.get(url, verify=False)
        # See https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
        
        folder_per_well = row['Well'].replace('/', '_')
        
        filedir = outdir + '\\' + folder_per_well
        
        if not os.path.exists(filedir):
            os.mkdir(filedir)
        
        with open('{}\{}'.format(filedir, filename), 'wb') as f:
            f.write(r.content)
        print('Saved to {}\{}'.format(filedir, filename))

        # Retrieve HTTP meta-data
        #print(r.status_code)
        #print(r.headers['content-type'])
        #print(r.encoding)
        
save_core_photo()
# Out:
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/87_01_4129-4135m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-3\87_01_4129-4135m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/87_02_4135-4141m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-3\87_02_4135-4141m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/87_03_4141-4148m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-3\87_03_4141-4148m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/87_04_4147-4186m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-3\87_04_4147-4186m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/87_05_4186-4192m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-3\87_05_4186-4192m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/87_06_4192-4198m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-3\87_06_4192-4198m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/87_07_4198-4203m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-3\87_07_4198-4203m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/87_08_4203-4209m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-3\87_08_4203-4209m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/87_09_4209-4215m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-3\87_09_4209-4215m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/87_10_4215-4221m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-3\87_10_4215-4221m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/87_11_4221-4227m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-3\87_11_4221-4227m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/87
.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-7\2505_116_3239-3244m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/2505_117_3244-3245m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-7\2505_117_3244-3245m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/2829_01_5024-5029m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-8\2829_01_5024-5029m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/2829_02_5029-5034m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-8\2829_02_5029-5034m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/2829_03_5034-5039m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-8\2829_03_5034-5039m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/3362_01_4273-4278m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-9 S\3362_01_4273-4278m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/3362_02_4278-4283m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-9 S\3362_02_4278-4283m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/3362_03_4283-4288m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-9 S\3362_03_4283-4288m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/3362_04_4288-4293m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-9 S\3362_04_4288-4293m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/3362_05_4293-4298m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-9 S\3362_05_4293-4298m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/3362_06_4298-4303m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-9 S\3362_06_4298-4303m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/3362_07_4303-4308m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-9 S\3362_07_4303-4308m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/3362_08_4308-4313m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-9 S\3362_08_4308-4313m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/3362_09_4313-4318m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-9 S\3362_09_4313-4318m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/3362_10_4318-4322m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-9 S\3362_10_4318-4322m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/3362_11_4323-4328m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-9 S\3362_11_4323-4328m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/3362_12_4328-4333m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-9 S\3362_12_4328-4333m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/3362_13_4333-4338m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-9 S\3362_13_4333-4338m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/3362_14_4338-4343m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-9 S\3362_14_4338-4343m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/3362_15_4343-4348m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-9 S\3362_15_4343-4348m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/3362_16_4348-4353m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-9 S\3362_16_4348-4353m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/3362_17_4353-4358m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-9 S\3362_17_4353-4358m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/3362_18_4358-4363m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-9 S\3362_18_4358-4363m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/3362_20_4368-4373m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-9 S\3362_20_4368-4373m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/3362_21_4373-4378m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-9 S\3362_21_4373-4378m.jpg
# Beginning file download with requests:  https://factpages.npd.no/pbl/core_photo_jpgs/3362_22_4378-4378m.jpg
# Saved to C:\ICData\Test3\core_photo_jpgs\1_3-9 S\3362_22_4378-4378m.jpg

# %% [markdown]
# ### Erroneous Core Photo Titles

# %%
# Import pre-conditioned file with Core Photo URLs

df = df_core_photo_ERRONEOUS_withURL

df = pd.read_csv('{}\output_data\wellbore_core_photo_ERRONEOUS_withURL.csv'.format(dbdir))
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-4bf53ea98ded> in <module>
#       1 # Import pre-conditioned file with Core Photo URLs
#       2
# ----> 3 df = df_core_photo_ERRONEOUS_withURL
#       4
#       5 df = pd.read_csv('{}\output_data\wellbore_core_photo_ERRONEOUS_withURL.csv'.format(dbdir))
#
# NameError: name 'df_core_photo_ERRONEOUS_withURL' is not defined

# %%
# See https://stackabuse.com/download-files-with-python/
# Using the request Module

# Would also be useful to create folders for each wellbore

def save_core_photo():
    
    for index, row in df.iterrows(): 
        # Using filterered dataframe for speed
        
        url = row['Core photo URL']
        filename = url.split('/')[-1]

        print('Beginning file download with requests: ', url)
        r = requests.get(url, verify=False)
        # See https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
        
        folder_per_well = row['Wellbore'].replace('/', '_')
        
        
        if not os.path.exists(outdir + '\Erroneous titles\\'):
            os.mkdir(outdir + '\Erroneous titles\\')
        
        filedir = outdir + '\Erroneous titles\\' + folder_per_well
        
        if not os.path.exists(filedir):
            os.mkdir(filedir)
        
        with open('{}\{}'.format(filedir, filename), 'wb') as f:
            f.write(r.content)
        print('Saved to {}\{}'.format(filedir, filename))

        # Retrieve HTTP meta-data
        #print(r.status_code)
        #print(r.headers['content-type'])
        #print(r.encoding)
        
save_core_photo()

# %%
# 

def save_core_photo():
    
    for index, row in df.iterrows(): 
        # Using filterered dataframe for speed
        
        url = row['Core photo URL']
        filename = url.split('/')[-1]

        print('Beginning file download with requests: ', url)
        r = requests.get(url, verify=False)
        
        with open('{}\{}'.format(outdir, filename), 'wb') as f:
            f.write(r.content)
        print('Saved to: {}\{}'.format(outdir, filename))

        # Retrieve HTTP meta-data
        print(r.status_code)
        print(r.headers['content-type'])
        print(r.encoding)
        
save_core_photo()

# %% [markdown]
# ## Check for overlap in Core Photo data

# %%
# IMPORTANT: This reads the pre-conditioned file "wellbore_core_photo.csv", generated by main script.

df_core_photo  = pd.read_csv('{}\output_data\wellbore_core_photo.csv'.format(dbdir))
print(df_core_photo.shape)
df_core_photo.head()

# %%
df_core_photo.isna().sum()

# %%
# Note overlapping depths in Core Photos
# For example in well 15/9-1

filt = df_core_photo['Well'] == '15/9-1'
df_core_photo[filt].head()

# %%
# Calculate overlap
# Zero overlap for first test in each well, no negative overlaps (representing gaps)
# Iterate over DataFrame rows as (index, Series) pairs.

for index, row in df_core_photo[1:].iterrows():
    
    current_row = df_core_photo.loc[index]
    last_row = df_core_photo.iloc[df_core_photo.index.get_loc(index) - 1]
    
    # Zero overlap for first test in each well
    if current_row['Well'] != last_row['Well']:
        df_core_photo.loc[index, 'Overlap'] = 0
    
    else:
        # Difference between base of last row and top of current row
        if current_row['Top depth'] < last_row['Base depth']:
            df_core_photo.loc[index, 'Overlap'] = last_row['Base depth'] - current_row['Top depth']
        else:
            df_core_photo.loc[index, 'Overlap'] = 0 

df_core_photo_overlap = df_core_photo.round(1)

# %%
# Where overlap > 0
df_core_photo_overlap[df_core_photo_overlap['Overlap'] > 0]

# %%
# Output to file
file = "output data/calc_corephoto_overlap_and_equal.xlsx"
df_core_photo_overlap.to_excel(file, index=False)
pd.read_excel(file).head(20)

# %%
# Count wells with overlap (say, over 10 m)

num_unique = len(df_core_photo_overlap['Well'].unique())

num_unique_problem = len(df_core_photo_overlap['Well'][df_core_photo_overlap['Overlap'] > 10].unique())

print('{} out of {} wells have overlap'.format(num_unique_problem, num_unique))

# %%
df_core_photo_overlap['Well'][df_core_photo_overlap['Overlap'] > 10].unique()

# %%
# Re-use code to find wells where depth values are same for many records
# i.e. where core photo depths do not increasy incrementally (and maybe share depth of full cored interval)
# e.g well 6507/7-4

filt = df_core_photo_overlap['Well'] == '6507/7-4'
df_core_photo_overlap[filt].head()

# %%
df_core_photo_overlap.sort_values('Overlap', ascending=False).head(30)

# %%
# 

for index, row in df_core_photo_overlap[1:].iterrows():
    
    current_row = df_core_photo_overlap.loc[index]
    last_row = df_core_photo_overlap.iloc[df_core_photo_overlap.index.get_loc(index) - 1]
    
    # Zero overlap for first test in each well
    if current_row['Well'] != last_row['Well']:
        df_core_photo_overlap.loc[index, 'Equal'] = '0'
    
    else:
        # If top of current row and top of last row are equal, then 1
        if current_row['Top depth'] == last_row['Top depth']:
            df_core_photo_overlap.loc[index, 'Equal'] = '1'
        else:
            df_core_photo_overlap.loc[index, 'Equal'] = '0'

df_core_photo_overlap_and_equal = df_core_photo_overlap.round(1)

# %%
# Output to file
file = "output data/calc_corephoto_overlap_and_equal.xlsx"
df_core_photo_overlap_and_equal.to_excel(file, index=False)
pd.read_excel(file).head(20)

# %%
filt = df_core_photo_overlap_and_equal['Well'] == '6507/7-4'
df_core_photo_overlap_and_equal[filt].head(10)

# %%
# Count number of equal rows per well
# E.g. Well 2/7-20 has 58 rows showing the same depths

test = df_core_photo_overlap_and_equal.groupby(['Well', 'Equal']).count()
test.head(50)

# %%
# Output to file
file = "output data/test.xlsx"
test.to_excel(file, index=False)
pd.read_excel(file).head(20)
